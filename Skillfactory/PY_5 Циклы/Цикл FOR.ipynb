# %% [markdown]
# ## <center> ЦИКЛ FOR

# %% [markdown]
# Тело цикла — это набор команд, находящихся на одном (4 пробела) и более отступе от отступа самого цикла.
#
# Другими словами, тело цикла — это те команды, которые находятся внутри него и будут повторяться. В упомянутом ранее примере тело цикла —

# %% [markdown]
# Итерация — это один шаг цикла, повторное применение операции, прописанной в теле цикла.
#
# Например, говоря «на пятой итерации цикла», мы будем иметь в виду, что рассматривается пятый шаг цикла и тело цикла выполняется в пятый раз.

# %% [markdown]
# В Python предусмотрено две встроенные конструкции, которые организуют цикл: цикл for и цикл while. Если вы читаете чей-то код и сталкиваетесь с ключевыми словами for и while, знайте — перед вами цикл.
#
# Мы начнём наш разбор с цикла for.

# %%
# Определяем итерируемый объект
my_list = [5, 9, 19]  
# Подставляем его в шаблон для цикла и записываем имя переменной цикла
for element in my_list: 
    # Указываем необходимые действия в тело цикла
    print('Element', element)
# Out:
# Element 5
# Element 9
# Element 19

# %% [markdown]
# #### <center> Совмещённые операторы

# %% [markdown]
# Перед тем как мы перейдём к рассмотрению примеров работы с циклами, нам необходимо познакомиться с популярными операторами, которые позволяют сокращать код.
#
# value = 10
# value = value + 1 #увеличили значение value на 1
#
# → Однако в Python для таких случаев предусмотрен более лаконичный оператор +=, который совмещает в себе оператор сложения (+) и оператор присваивания (=). Оператор суммирует значения справа и слева и записывает результат в переменную.
#
# Увеличение переменной value можно переписать так:
#
# value = 10
# value += 1 #увеличили значение value на 1

# %% [markdown]
# Длинная запись
# value = value + a
# value = value - a
# value = value / a
# value = value * a
# value = value ** a

# %% [markdown]
# Сокращённая запись
# value += a
# value -= a
# value /= a
# value *= a
# value **= a

# %% [markdown]
# ##### Задача №1
#
# Условие задачи. Дан список доходов членов семьи Быковых (в тысячах рублей).
# incomes = [120, 38.5, 40.5, 80]
# Необходимо найти общий доход семьи.

# %%
# Задаём список доходов семьи Быковых
incomes = [120, 38.5, 40.5, 80]
# Задаём начальное значение суммы доходов 
S = 0 
# Создаём цикл for, в котором будем проходиться по элементам списка incomes.
# income — текущее значение элемента списка
for income in incomes: 
    # Выводим текущее значение переменной income
    print('Current income', income)   
    # Выводим текущее значение переменной S  
    print('Current S', S) 
    # Увеличиваем сумму доходов на значение income
    # Равносильно S = S + income
    S += income 
    # Выводим обновлённое значение переменной S
    print('New S', S)
    # Выводим пустую строку для красивого отображения 
    print() 
# Выводим результат 
print('Answer: s=', S)
# Out:
# Current income 120
# Current S 0
# New S 120
#
# Current income 38.5
# Current S 120
# New S 158.5
#
# Current income 40.5
# Current S 158.5
# New S 199.0
#
# Current income 80
# Current S 199.0
# New S 279.0
#
# Answer: s= 279.0

# %% [markdown]
# Комментарий по работе цикла
#
# На каждой итерации цикла в переменную income записывается значение из списка incomes.
# В теле цикла с помощью функции print() выводится текущее значение переменной income, то есть то значение, которое находится в переменной на рассматриваемой итерации, а также выводится текущее значение переменной S (до её обновления).
# Далее к текущему значению S прибавляется значение income.
# Выводится новое значение переменной S и пустая строка для более приятного глазу отображения работы кода на экране.
# Далее цикл переходит на новый этап, и из списка incomes извлекается следующее значение. Операции повторяются до тех пор, пока в списке incomes не закончатся элементы.
# Оператор S += income означает S = S + income в сокращённом виде.

# %% [markdown]
# #### Задача №2

# %% [markdown]
# Условие задачи. Найти сумму всех натуральных чисел от 1 до N включительно.
# Натуральные числа — это числа 1, 2, 3, 4 и т. д.
#
# Разберём алгоритм решения задачи.
#
# Как и в прошлой задаче, для начала нам нужно создать переменную, в которой мы будем суммировать все числа. Пусть это будет переменная S.
# Возникает вопрос: где нам взять последовательность чисел от 1 до N включительно? Не создавать же нам её вручную?
# Если N = 500, то ручное создание списка чисел от 0 до N может стать настоящей проблемой!
# Здесь на помощь приходит функция range(), которая как раз создаст последовательность целых чисел. Мы уже упоминали о ней в модуле по типам данных.

# %% [markdown]
# Теперь у нас есть все необходимые знания, чтобы выполнить нашу задачу с помощью цикла for. Итак, согласно нашему алгоритму создания цикла for, мы должны задать:
# Итерируемый объект — это будет последовательность чисел от 1 до N включительно (N задаётся заранее и может быть произвольным). Мы создадим её с помощью функции range(). Так как по условию число N должно быть включено в последовательность, то аргумент STOP будет равен N+1.
# Действие в цикле — прибавить к заданной переменной S число из последовательности. Дополнительно будем выводить текущее значение S, текущее значение переменной цикла и обновлённое значение S.
#
# Теперь, проходя по последовательности чисел на каждом новом шаге цикла, мы будем брать число из диапазона range() и записывать его в нашу переменную-счётчик, которую традиционно называют i. Далее в цикле на каждой итерации мы будем прибавлять текущее значение i к нашей накопительной переменной суммы.

# %%
# Создаём накопительную переменную, в которой будем считать сумму.
S = 0  
# Задаём N — последний элемент последовательности
N = 2 


# Создаём цикл for, которым будем проходить по всем числам от 1 до N (включительно).
# Равносильно выражению for i in [1, 2, 3, ... , N -1, N]:
for i in range(1, N + 1):  
    # Выводим значение суммы на текущем шаге
    print("Current S: ", S) 
    # Выводим текущее число
    print("Current number: ", i) 
    # Суммируем текущее число i и перезаписываем значение суммы
    # Равносильно S = S + i
    S += i  
    # Выводим значение суммы после сложения
    print("Sum after addition: ", S)
    # Выводим строчку для визуального разделения результатов 
    print("---") 


# Выводим ответ в формате “ответ: сумма равна =”
print("Answer: sum = ", S)
# Out:
# Current S:  0
# Current number:  1
# Sum after addition:  1
# ---
# Current S:  1
# Current number:  2
# Sum after addition:  3
# ---
# Answer: sum =  3

# %%
print(list(range(20,1,-2)))
# Out:
# [20, 18, 16, 14, 12, 10, 8, 6, 4, 2]

# %% [markdown]
# #### Задача №3

# %% [markdown]
# Условие задачи. Представим, что мы пишем программу для компании, занимающейся грузоперевозками.
# В нашем распоряжении есть список масс товаров, предназначенных для перевозки (в килограммах).
# Согласно нашим данным, товары, которые весят больше 100 килограммов, необходимо перевозить на грузовой машине, а товары меньшей массы можно перевезти на легковой.
# → Необходимо написать алгоритм, который распределял бы товары по типам машин.
# Пример списка товаров (грузов):
#
# weight_of_products= [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]

# %% [markdown]
# Итак, давайте обсудим алгоритм решения задачи.
#
# Для начала нам надо задать максимальный вес груза. Занесём его в переменную max_weight. Далее нам необходимо перебрать массы товаров в цикле. В теле цикла зададим условие: масса текущего товара < 100 кг. Если данное условие выполняется, будем выводить на экран номер товара, его вес и фразу «-passenger car». В противном случае выводим то же самое, но меняем фразу на «-truck».
#
# Задачу прохода по элементам списка в цикле можно решить двумя способами.

# %% [markdown]
# ##### Способ 1. Цикл по элементам списка

# %% [markdown]
# При этом способе для нумерации товаров нам понадобится дополнительная переменная num, которая будет обозначать номер груза (номера будем считать с единицы). До начала выполнения цикла она будет равна 1. В процессе выполнения цикла будем увеличивать порядковый номер на 1.
#
# Давайте вновь обратимся к алгоритму создания цикла for и определим наши компоненты:
#
# Итерируемый объект — список товаров (грузов) weight_of_products.
# Действие в цикле — сравнить элемент списка с заданным максимальным значением веса и в зависимости от выполнения данного условия выводить на экран номер груза, его вес и тип машины для перевозки. Не забыть увеличить номер груза на 1 для следующей итерации цикла.

# %%
# Задаём список значений массы товаров
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15] 


# Задаём максимальное значение веса груза
max_weight = 100 
# Задаём начальный номер груза
num = 1 
# Создаём цикл по элементам списка со значениями массы товаров
# weight — текущее значение веса
for weight in weight_of_products: 
    # Если текущий вес меньше максимального,
    if weight < max_weight: 
        # выводим номер груза, его вес и отправляем его в легковую машину.
        print('Product {}, weight: {} -passenger car'.format(num, weight)) 
    else:
        # В противном случае
        # выводим номер груза, его вес и отправляем его в грузовую машину.
        print('Product {}, weight: {} -truck'.format(num, weight))
    # Увеличиваем значение номера груза на 1
    num += 1
# Out:
# Product 1, weight: 10 -passenger car
# Product 2, weight: 42.4 -passenger car
# Product 3, weight: 240.1 -truck
# Product 4, weight: 101.5 -truck
# Product 5, weight: 98 -passenger car
# Product 6, weight: 0.4 -passenger car
# Product 7, weight: 0.3 -passenger car
# Product 8, weight: 15 -passenger car

# %% [markdown]
# ##### Способ 2. Цикл по индексам списка

# %% [markdown]
# Для реализации прохода по элементам списка можно использовать более сложный, но в то же время более универсальный вариант. Как вы помните, для обращения к элементам списка можно использовать операцию индексации (квадратные скобки, в которых указывается индекс элемента, который мы хотим получить).
#
# Идея подхода заключается в следующем: в цикле будем перебирать целые числа от 0 до N (не включая N), где N — это длина списка (в нашем случае N = 8). Это будут индексы списка. Числа из последовательности будем заносить в переменную i (на первой итерации i = 0, на второй — i = 1, на третьей — i = 2 и т. д).
#
# Далее в самом теле цикла мы будем обращаться к списку по индексу, получать его элементы — массы товаров, сравнивать их с максимальным значением max_weight и выводить на экран информацию о товаре и типе машины для его перевозки.
#
# В данном подходе компоненты следующие:
#
# Итерируемый объект — последовательность чисел от 0 до N, не включая N (индексы списка).
# Действие в цикле — обратиться к элементу по индексу, сравнить его с заданным максимальным значением веса и в зависимости от выполнения условия выводить на экран номер товара, массу и тип машины для перевозки. Номер товара рассчитывается как индекс + 1, так как цикл идёт по индексам от 0, а мы условились, что номера товаров начинаются с 1.

# %%
# Задаём список значений массы товаров
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15] 
# Задаём максимальное значение веса груза
max_weight = 100 
# Вычисляем длину списка
N = len(weight_of_products) 
# Создаём цикл по последовательности чисел от 0 до N (не включая N)
# i — текущее значение последовательности
for i in range(N): 
    # Обращаемся к элементу по индексу и сравниваем его с максимумом
    if weight_of_products[i] < max_weight:
        # Если текущий вес меньше максимального,
        # выводим номер груза, его массу и отправляем его в легковую машину.
        print('Product {}, weight: {} -passenger car'.format(i+1, weight_of_products[i])) 
    else:
        # В противном случае
        # выводим номер груза, его массу и отправляем его в грузовую машину
        print('Product {}, weight: {} -truck'.format(i+1, weight_of_products[i]))
# Out:
# Product 1, weight: 10 -passenger car
# Product 2, weight: 42.4 -passenger car
# Product 3, weight: 240.1 -truck
# Product 4, weight: 101.5 -truck
# Product 5, weight: 98 -passenger car
# Product 6, weight: 0.4 -passenger car
# Product 7, weight: 0.3 -passenger car
# Product 8, weight: 15 -passenger car

# %% [markdown]
# На каждой итерации цикла в переменную i заносится число из последовательности от 0 до N (не включая N). В нашем случае N = 8. Далее эта переменная используется в качестве индекса списка. По нему мы получаем значение i-го элемента списка, сравниваем его со значением переменной max_weight и используем значение i для вывода номера груза. Когда заканчивается выполнение тела цикла, происходит переход на новую итерацию, в переменную i записывается следующее значение из последовательности, и тело цикла повторяется. Итерации продолжаются, пока i не достигнет значения N — тогда цикл завершает свою работу.

# %% [markdown]
# ##### Задача №4

# %% [markdown]
# Условие задачи. Мы разрабатываем новый функционал приложения для туристического агентства «Ковёр-самолёт». В нашем распоряжении есть список мест places, которые пользователь хотел бы посетить.
#
# places = [
#     'Red Square',
#     'Swallow Nest',
#     'Niagara Falls',
#     'Grand Canyon',
#     'Louvre',
#     'Hermitage'
# ]
#
# Также есть словарь location, ключи которого — места, которые пользователь хочет посетить, а значения — названия стран, где находятся эти места.
#
# location = {
#     'Red Square': 'Russia',
#     'Swallow Nest': 'Russia',
#     'Niagara Falls': 'USA',
#     'Grand Canyon': 'USA',
#     'Louvre': 'France',
#     'Hermitage': 'Russia'
# }
#
# По эпидемиологическим причинам пользователь не может посетить места, которые находятся вне территории России. Наша задача — заменить заграничные места в списке places на значение 'Unavailable'.

# %% [markdown]
# Способ 1 (неверный). Цикл по элементам списка
#
# Будем проходиться в цикле по элементам списка places — местам, которые пользователь хотел бы посетить. Место заносим в переменную place. Далее в цикле обращаемся по ключу (названию места) к словарю location и выясняем страну, в которой находится данное место. Сравниваем значение страны со строкой 'Russia'. Если равенство не выполняется, то заменяем значение переменной place на строку 'Unavailable', в противном случае ничего не делаем (блок else в данном случае даже не указываем). Наконец, после завершения выполнения цикла выводим результирующий список places на экран.

# %%
# Список мест, которые хотим посетить.
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
# Словарь соответствия мест и стран
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}
# Создаём цикл по списку мест, которые хотим посетить.
# place — текущее название места
for place in places: 
    # Получаем страну из словаря location по ключу
    country = location[place] 
    # Сравниваем название страны
    if country != 'Russia': 
        # Помечаем место как недоступное
        place = 'Unavailable' 
# Выводим результирующий список
print(places)


## Будет выведено:
## ['Red Square', 'Swallow Nest', 'Niagara Falls', 'Grand Canyon', 'Louvre', 'Hermitage']
# Out:
# ['Red Square', 'Swallow Nest', 'Niagara Falls', 'Grand Canyon', 'Louvre', 'Hermitage']

# %% [markdown]
# Список places не изменился! Почему не работает? Синтаксис ведь верный...

# %% [markdown]
# Ответ одновременно и сложен, и прост. Оказывается, когда мы перебираем в цикле элементы списка places, переменная place ссылается на строки, которые являются неизменяемыми объектами. Поэтому при изменении значения переменной place на 'Unavailable' её значение просто перезаписывается, однако сам объект при этом не изменяется.
#
# Например, на третьей итерации цикла переменная place ссылается на строку 'Niagara Falls'. Изменяя значение переменной на строку 'Unavailable', мы изменяем ссылку, но не само значение, то есть строка 'Niagara Falls' так и остаётся лежать в списке places. Изменится только значение переменной place внутри тела цикла.

# %% [markdown]
# Способ 2. Цикл по индексам списка
#
# Попробуем модифицировать наш алгоритм. Теперь будем проходиться в цикле по индексам нашего списка — это будет цикл по целым числам от 0 до N (не включая N), где N — длина списка places. Числа из последовательности будем заносить в переменную i.
#
# Логика работы тела цикла остаётся прежней, но с одним важным изменением: теперь для обращения к месту из списка places мы будем использовать его индекс. Если i-е место находится не в России, заменяем i-й элемент списка на строку 'Unavailable'.

# %%
# Список мест, которые хотим посетить.
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
# Словарь соответствия мест и стран
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}
# Вычисляем длину списка
N = len(places)
# Создаём цикл по списку мест, которые хотим посетить.
# i — текущее значение последовательности
for i in range(N):
    # places[i] — i-й элемент в списке places
    # Получаем страну из словаря location по ключу
    country = location[places[i]]
    # Сравниваем название стран
    if country != 'Russia':
        # Помечаем место как недоступное
        places[i] = 'Unavailable'
# Выводим результирующий список
print(places)


## Будет выведено:
## ['Red Square', 'Swallow Nest', 'Unavailable', 'Unavailable', 'Unavailable', 'Hermitage']
# Out:
# ['Red Square', 'Swallow Nest', 'Unavailable', 'Unavailable', 'Unavailable', 'Hermitage']

# %% [markdown]
# Для того чтобы обращаться не к копии элемента, а к самому элементу, необходимо обращаться к нему от имени списка. То есть чтобы заменить элемент под индексом 2 ('Niagara Falls'), нам необходимо обратиться к нему от имени списка places[2] и через оператор присваивания (=) задать ему новое значение.

# %% [markdown]
# Мы рассмотрели очень показательный пример, из которого нам надо сделать важные выводы по работе цикла for со списками:
#
# Если внутри тела цикла for не предполагается изменение списка, по которому проходят итерации, предпочтительнее использовать цикл по элементам списка, т. е. итерируемый объект — сам список. Примеры: вывод содержимого списка на экран, сложение элементов списка, подсчёт элементов по условию (подсчитать, сколько в списке чисел, а сколько строк), передача элементов списка в сторонние функции (отправка сообщений по почте).
# Если вы заранее знаете, что внутри тела функции будете изменять список, то цикл ведётся по индексам списка. Цикл по индексам может вестись в случаях, когда в вычислениях участвует не один элемент списка, а сразу несколько. Рассмотрим такой пример чуть позже.
